# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('sdg_index.csv',index_col="year")

# %%
df.head()
# Out:
#      country_code      country  sdg_index_score  goal_1_score  goal_2_score  \
# year
# 2000          AFG  Afghanistan             36.0          28.8          27.3
# 2001          AFG  Afghanistan             36.3          28.8          30.6
# 2002          AFG  Afghanistan             36.3          28.8          30.7
# 2003          AFG  Afghanistan             36.7          28.8          32.5
# 2004          AFG  Afghanistan             37.1          28.8          32.1
#
#       goal_3_score  goal_4_score  goal_5_score  goal_6_score  goal_7_score  \
# year
# 2000          19.2           1.6          20.8          32.4          21.0
# 2001          19.4           1.6          20.8          32.4          22.3
# 2002          19.7           1.6          20.8          32.7          21.5
# 2003          19.9           1.6          20.8          33.0          24.5
# 2004          21.1           1.6          20.8          33.3          28.0
#
# ...
